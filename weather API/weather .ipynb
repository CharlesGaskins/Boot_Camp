# %%
#Dependencies

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import openweathermapy as owm
import pprint
from pandas.io.json import json_normalize

# Import API key
from config import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
 
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count

cities=cities[0:550]
len(cities)
# Out:
# 550

# %%
# list for response results
pressure = []
temp=[]
humidity=[]
cloudiness=[]
wind=[]
lat = []
wind=[]
#city = []
units = "metric"

# %%
for city in cities:
    print("1")
    url = "http://api.openweathermap.org/data/2.5/weather?"
    query_url = url + "appid=" + api_key + "&q=" +city
    #query_url = url + "appid=" + api_key + "&q=" + name
    weather_response = requests.get(query_url)
    print("2")
    weather_json = weather_response.json()
    print(json.dumps(weather_json,sort_keys=True, indent=4))
    json.dumps(weather_json,sort_keys=True, indent=4)
    #pprint.pprint(weather_json)
#data=pd.DataFrame.from_dict(json_normalize(weather_json))
#data=data.reset_index()
#data.set_index('name',inplace=True)
#len(data)
    #print(json.dumps(weather_json, indent=4))
    count=500
    if("main" in weather_json):
        
     
        temp.append(weather_json["main"]["temp"])
        pressure.append(weather_json["main"]["pressure"])
        humidity.append(weather_json["main"]["humidity"])
        cloudiness.append(weather_json["clouds"]["all"])
        wind.append(weather_json["wind"]["speed"])
        lat.append(weather_json["coord"]["lat"])
        #city.append(weather_json["name"])
        
        #city.append("name")
        #cloudiness.append(city[cloudiness])
        #humidity.append(city[humidity])
        #temp.append(city[temperature])
        #pressure.append(city[pressure])
        #wind.append(city[wind])
        #lat.append(city[lat])
        #print("Main found for: " + name)
        
weather_df=pd.DataFrame({'temperature':temp,'pressure':pressure,'humidity':humidity,'cloudiness':cloudiness,'wind':wind,'city':city,"lat":lat})
# Out:
# 1
# 2
# {
#     "base": "stations",
#     "clouds": {
#         "all": 8
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -34.53,
#         "lon": 20.04
#     },
#     "dt": 1532034000,
#     "id": 1015776,
#     "main": {
#         "humidity": 22,
#         "pressure": 1018,
#         "temp": 297.15,
#         "temp_max": 297.15,
#         "temp_min": 297.15
#     },
#     "name": "Bredasdorp",
#     "sys": {
#         "country": "ZA",
#         "id": 6591,
#         "message": 0.0038,
#         "sunrise": 1531978916,
#         "sunset": 1532015444,
#         "type": 1
#     },
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "02n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 40,
#         "speed": 4.1
#     }
# }
# 1
# 2
# {
#     "base": "stations",
#     "clouds": {
#         "all": 92
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 22.57,
# ...

# %%
#weather_df

# %%
weather_df.to_csv("weather.csv")
csvfile="weather.csv"
df=pd.read_csv(csvfile)
#df

# %%
#Your objective is to build a series of scatter plots to showcase the following relationships:



#Wind Speed (mph) vs. Latitude

# %%
plt.scatter(df['temperature'], df['lat'], marker='o',facecolors='red',edgecolors='black')

plt.title("TEMP VS LAT")
plt.xlabel("Temperature (Celsius)")
plt.ylabel("LATITUDE")
# Out:
# Text(0,0.5,'LATITUDE')

# %%
df['temperature'].count()
# Out:
# 499

# %%
plt.scatter(df['humidity'], df['lat'], marker='o',facecolors='green',edgecolors='black')
plt.title("HUMIDITY VS LAT")
plt.xlabel("HUMIDITY")
plt.ylabel("LATITUDE")
# Out:
# Text(0,0.5,'LATITUDE')

# %%
plt.scatter(df['cloudiness'], df['lat'], marker='o',facecolors='pink',edgecolors='black')
plt.title("CLOUDINESS VS LAT")
plt.xlabel("CLOUDINESS")
plt.ylabel("LATITUDE")
# Out:
# Text(0,0.5,'LATITUDE')

# %%
plt.scatter(df['wind'], df['lat'], marker='o',facecolors="orange",edgecolors='black')

plt.title("WIND SPEED VS LAT")
plt.xlabel("WIND SPEED")
plt.ylabel("LATITUDE")
# Out:
# Text(0,0.5,'LATITUDE')

# %% [markdown]
# 3 observations
#
#
# - latitude doesnt seem to have a real effect on windspeed
#
# - Humidity isnt overly affected by latitude but most of the groupings seems to cluster a bit more from 0 degrees and up
#
# - there is a unique curvature with temp and latitude
